# %% [markdown]
# The Ministerio de Educacion of Spain has contacted the school
# to get some help. He wants you to do a thorough analysis of the impact that
# some student characteristics have on student performance.
# It's time to put those new modelling skills into practice!

# %%
import pandas as pd
data = pd.read_csv('../data/spain.csv')
data
# Out:
#        mother_has_secondary_education  mother_has_college_education  \
# 0                                 1.0                           1.0
# 1                                 1.0                           1.0
# 2                                 1.0                           1.0
# 3                                 1.0                           1.0
# 4                                 1.0                           1.0
# ...                               ...                           ...
# 35938                             1.0                           1.0
# 35939                             1.0                           1.0
# 35940                             1.0                           1.0
# 35941                             1.0                           1.0
# 35942                             1.0                           1.0
#
#        birth_month_num birth_month_name  gender internet_connection  \
# 0                    9        September    Male                 Yes
# 1                    8           August  Female                 Yes
# 2                   11         November  Female                 Yes
# 3                    5              May    Male                 Yes
# 4                    2         February  Female                 Yes
# ...                ...              ...     ...                 ...
# 35938                3            March  Female                 Yes
# 35939                7             July  Female                 Yes
# 35940               10          October  Female                 Yes
# 35941                5              May    Male                 Yes
# 35942                2         February  Female                 Yes
#
#       repeated_secondary  score_math  n_students_in_school
# 0              No, never    468.2330                  75.0
# 1              No, never    539.3369                  75.0
# 2              No, never    619.6046                  75.0
# 3              No, never    406.1378                  75.0
# 4              No, never    508.2389                  75.0
# ...                  ...         ...                   ...
# 35938          No, never    494.6956                 153.0
# 35939          No, never    582.8701                 153.0
# 35940          No, never    546.3091                 153.0
# 35941          No, never    623.5066                 153.0
# 35942          No, never    597.9505                 153.0
#
# [35943 rows x 9 columns]

# %% [markdown]
# 1. Do some EDA on it. Plot the distributions using some of the visualisations we've learnt in class. Try also to visualise bivariate relationships with our target.
# 2. Prepare the data for modelling. You'll have to deal with missing values. Also, you'll have to turn categorical features into a format that an ML model can take.
# 3. Fit a linear model and analyse the results. What do you see? Analyse the impact that those features have on student performance. Do they have a significative impact?
