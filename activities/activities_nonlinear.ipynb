# %% [markdown]
# The CEO of CodeOp happens to be friends to Jesus Encinar,
# the CEO of idealista (a portal to buy and sell houses) and has been talking to him
# over diner about your great work. Jesus couldn't be more excited about
# it and has contacted the school to ask one of the students for some help.
# They want to be able to provide pricing advice in an automatic way, so that
# when a customer wants to list a house on their platform, they get recommended
# how much to tag it for. He's heard you've studied some fancy ML models and
# would like you to use them to predict the price of new houses.
#
# First part: Do some EDA. You have already seen this
# dataset before, but it might still be good to do some further analysis,
# since you might want to use more variables than last time.
#
# Second part: Build a baseline model. The baseline model has to be simple, so you're
# sure it works and provides a benchmark that you'll have to beat. Split your data
# in train and test. Train your model and generate some predictions on the test set.
# How good is your model? You can use any of the error functions (MSE or MAE) we've seen in the course
# to answer that question.
#
# Third part: Beat your baseline. There's three ways to beat a model: play with the feature
# matrix (add/remove features, create new ones...), try different models (linear regression, decision-trees,
# random forest...) and tuning hyperparameters (not yet explained in class). Try playing with
# the first two to beat your baseline performance. At every point, store the performance of the model
# with some identifier so you can keep track of what model is doing the best.
#
# The objective of this assignment is to get used to the flow of setting a baseline and trying to beat it.
# I would recommend you to use only numerical features, but if you want to use categorical features
# give a look to pd.get_dummies.
#
# Remember, for any question about the dataset you can either contact me or check Kaggle's documentation
# on the dataset: https://www.kaggle.com/c/house-prices-advanced-regression-techniques

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/CodeOp-tech/DA-ML-regression-predictive-solutions/master/datasets/housing.csv?token=AHM3F3DPWKQDVT6CJWLSD4DAPGZ4M')
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1455  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1456  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1457  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1458  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...
